# %%
# !git clone https://github.com/hammaad2002/NILM-Project
# Out:
# Cloning into 'NILM-Project'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (53/53), done.
# Receiving objects: 100% (60/60), 29.35 KiB | 3.67 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# remote: Total 60 (delta 25), reused 11 (delta 5), pack-reused 0

# %%
# %cd /kaggle/working/NILM-Project
# Out:
# /kaggle/working/NILM-Project

# %%
# !pwd
# Out:
# /kaggle/working/NILM-Project

# %%
# %cd /kaggle/working/NILM-Project/
# !python REDD_Parser.py 
# !python UKDALE_Parser.py
# !python Refit_Parser.py
# !python Pretrain_Dataset.py
# !python NILM_Dataset.py
# !python NILM_Dataloader.py
# !python model_helpers.py
# !python metrics.py
# !python config.py
# !python Electricity_model.py
# !python Trainer.py
# !python3 electricityy.py
# Out:
# /kaggle/working/NILM-Project
# Failed to load old model, continue training new model...
# Validation, rel_err 0.09, acc 0.91, f1 0.00: 100%|█| 58/58 [00:08<00:00,  6.47it
# Saving best model...
# ...
# Epoch 1, loss 0.77:  34%|██████▊             | 354/1044 [01:09<02:16,  5.06it/s]
# Traceback (most recent call last):
#   File "electricityy.py", line 45, in <module>
#     trainer.train()
#   File "/kaggle/working/NILM-Project/Trainer.py", line 107, in train
#     self.pretrain_one_epoch(epoch+1)
#   File "/kaggle/working/NILM-Project/Trainer.py", line 149, in pretrain_one_epoch
#     loss_values.append(total_loss.item())
# KeyboardInterrupt
